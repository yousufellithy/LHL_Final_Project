# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('credit_record.csv')

# %%
df1['ID'].nunique()
# Out:
# 45985

# %%
df2 = pd.read_csv('application_record.csv')

# %%
df2['ID'].nunique()
# Out:
# 438510

# %%
df1.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
df2.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
dfstatus = df1.copy()

# %%
dfinfo = df2.copy()

# %%
dfinfo[dfinfo['ID'] == 5001711]
# Out:
# Empty DataFrame
# Columns: [ID, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE, FLAG_EMAIL, OCCUPATION_TYPE, CNT_FAM_MEMBERS]
# Index: []

# %%
dfinfo.sort_values(by='ID')
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 423317  7999660           F            N               N             0
# 426434  7999696           F            N               Y             2
# 432885  7999738           M            N               Y             0
# 421225  7999784           F            Y               Y             1
# 424339  7999952           F            N               Y             1
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dfstatus.sort_values(by='ID')
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 22       5001712             -18      0
# ...          ...             ...    ...
# 1048547  5150487              -2      C
# 1048546  5150487              -1      C
# 1048545  5150487               0      C
# 1048558  5150487             -13      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
dfstatus = dfstatus.sort_values(by='ID')
dfinfo = dfinfo.sort_values(by='ID')

result_df = pd.merge(dfstatus, dfinfo, on='ID', how='inner')

# %%
result_df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804             -15      X           M            Y
# 1       5008804             -14      0           M            Y
# 2       5008804             -13      1           M            Y
# 3       5008804             -12      C           M            Y
# 4       5008804             -11      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487              -2      C           M            Y
# 777711  5150487              -1      C           M            Y
# 777712  5150487               0      C           M            Y
# 777713  5150487             -13      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                    Y             0          427500.0          Working
# ...

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   MONTHS_BALANCE       777715 non-null  int64
#  2   STATUS               777715 non-null  object
#  3   CODE_GENDER          777715 non-null  object
#  4   FLAG_OWN_CAR         777715 non-null  object
#  5   FLAG_OWN_REALTY      777715 non-null  object
#  6   CNT_CHILDREN         777715 non-null  int64
#  7   AMT_INCOME_TOTAL     777715 non-null  float64
#  8   NAME_INCOME_TYPE     777715 non-null  object
#  9   NAME_EDUCATION_TYPE  777715 non-null  object
#  10  NAME_FAMILY_STATUS   777715 non-null  object
#  11  NAME_HOUSING_TYPE    777715 non-null  object
#  12  DAYS_BIRTH           777715 non-null  int64
#  13  DAYS_EMPLOYED        777715 non-null  int64
#  14  FLAG_MOBIL           777715 non-null  int64
# ...

# %%
result_df['STATUS'].value_counts()
# Out:
# STATUS
# C    329536
# 0    290654
# X    145950
# 1      8747
# 5      1527
# 2       801
# 3       286
# 4       214
# Name: count, dtype: int64

# %%
result_df['STATUS'] == 'C'
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 777710     True
# 777711     True
# 777712     True
# 777713     True
# 777714     True
# Name: STATUS, Length: 777715, dtype: bool

# %%
def status(row):
    if row['STATUS'] == 'C':
        return 'On-time'
    elif row['STATUS'] == 'X':
        return 'No loan'
    else: 
        return 'Late'


result_df['Payments'] = result_df.apply(status, axis=1)

# %%
result_df['Payments'].value_counts()
# Out:
# Payments
# On-time    329536
# Late       302229
# No loan    145950
# Name: count, dtype: int64

# %%
result_df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0  5008804             -15      X           M            Y               Y
# 1  5008804             -14      0           M            Y               Y
# 2  5008804             -13      1           M            Y               Y
# 3  5008804             -12      C           M            Y               Y
# 4  5008804             -11      C           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  ...  \
# 0             0          427500.0          Working    Higher education  ...
# 1             0          427500.0          Working    Higher education  ...
# 2             0          427500.0          Working    Higher education  ...
# 3             0          427500.0          Working    Higher education  ...
# 4             0          427500.0          Working    Higher education  ...
#
# ...

# %%
result_df.rename(columns = {'AMT_INCOME_TOTAL': 'Annual_Income'}, inplace=True)

# %%
result_df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804             -15      X           M            Y
# 1       5008804             -14      0           M            Y
# 2       5008804             -13      1           M            Y
# 3       5008804             -12      C           M            Y
# 4       5008804             -11      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487              -2      C           M            Y
# 777711  5150487              -1      C           M            Y
# 777712  5150487               0      C           M            Y
# 777713  5150487             -13      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  Annual_Income NAME_INCOME_TYPE  \
# 0                    Y             0       427500.0          Working
# ...

# %%
df = result_df.copy()

# %%
df['FLAG_OWN_CAR'].value_counts()
# Out:
# FLAG_OWN_CAR
# N    473355
# Y    304360
# Name: count, dtype: int64

# %%
df.rename(columns ={'FLAG_OWN_CAR': 'Car', 'FLAG_OWN_REALTY': 'Property', 'CODE_GENDER': 'Gender', 'NAME_INCOME_TYPE': 'Income_Type', 'NAME_EDUCATION_TYPE': 'Education_level', 'NAME_FAMILY_STATUS': 'Family_Status', 'NAME_HOUSING_TYPE': 'Housing'}, inplace=True)

# %%
df['FLAG_OWN_REALTY'].value_counts()
# Out:
# FLAG_OWN_REALTY
# Y    512948
# N    264767
# Name: count, dtype: int64

# %%
df['CODE_GENDER'].value_counts()
# Out:
# CODE_GENDER
# F    518851
# M    258864
# Name: count, dtype: int64

# %%
df['NAME_INCOME_TYPE'].value_counts()
# Out:
# NAME_INCOME_TYPE
# Working                 400164
# Commercial associate    183385
# Pensioner               128392
# State servant            65437
# Student                    337
# Name: count, dtype: int64

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# NAME_HOUSING_TYPE
# House / apartment      697151
# With parents            35735
# Municipal apartment     24640
# Rented apartment        10898
# Office apartment         5636
# Co-op apartment          3655
# Name: count, dtype: int64

# %%
cols = ['FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL']

for col in cols:
    print(df[col].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FLAG_WORK_PHONE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.drop(cols, axis=1, inplace=True)
df.drop('FLAG_MOBIL', axis=1, inplace=True)

# %%
df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS Gender Car Property  CNT_CHILDREN  \
# 0  5008804             -15      X      M   Y        Y             0
# 1  5008804             -14      0      M   Y        Y             0
# 2  5008804             -13      1      M   Y        Y             0
# 3  5008804             -12      C      M   Y        Y             0
# 4  5008804             -11      C      M   Y        Y             0
#
#    Annual_Income Income_Type   Education_level   Family_Status  \
# 0       427500.0     Working  Higher education  Civil marriage
# 1       427500.0     Working  Higher education  Civil marriage
# 2       427500.0     Working  Higher education  Civil marriage
# 3       427500.0     Working  Higher education  Civil marriage
# 4       427500.0     Working  Higher education  Civil marriage
#
#             Housing  DAYS_BIRTH  DAYS_EMPLOYED OCCUPATION_TYPE  \
# 0  Rented apartment      -12005          -4542             NaN
# ...

# %%
df.describe()
# Out:
#                  ID  MONTHS_BALANCE   CNT_CHILDREN  Annual_Income  \
# count  7.777150e+05   777715.000000  777715.000000   7.777150e+05
# mean   5.078743e+06      -19.373564       0.428082   1.885348e+05
# std    4.180442e+04       14.082208       0.745755   1.016225e+05
# min    5.008804e+06      -60.000000       0.000000   2.700000e+04
# 25%    5.044568e+06      -29.000000       0.000000   1.215000e+05
# 50%    5.069530e+06      -17.000000       0.000000   1.620000e+05
# 75%    5.115551e+06       -8.000000       1.000000   2.250000e+05
# max    5.150487e+06        0.000000      19.000000   1.575000e+06
#
#           DAYS_BIRTH  DAYS_EMPLOYED  CNT_FAM_MEMBERS
# count  777715.000000  777715.000000    777715.000000
# mean   -16124.937046   57775.825016         2.208837
# std      4104.304018  136471.735391         0.907380
# min    -25152.000000  -15713.000000         1.000000
# 25%    -19453.000000   -3292.000000         2.000000
# ...

# %%
df['DAYS_BIRTH'] = df['DAYS_BIRTH']/365

# %%
df['DAYS_BIRTH'] = abs(df['DAYS_BIRTH'])

# %%
df['DAYS_BIRTH'] = np.floor(df['DAYS_BIRTH'])

# %%
df.rename(columns= {'DAYS_BIRTH': 'Age', 'DAYS_EMPLOYED': 'Years_Employed', 'OCCUPATION_TYPE': 'Occupation_Type'}, inplace=True

# %%
def employment_time(row):
    if row['Years_Employed'] >= 0:
        return 0
    else:
        return np.floor(row['Years_Employed']/365)

df['Years
   
df['Years_Employed'] = df['Years_Employed']/365
df['Years_Employed'] = abs(df['Years_Employed'])

# %%
df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS Gender Car Property  CNT_CHILDREN  \
# 0  5008804             -15      X      M   Y        Y             0
# 1  5008804             -14      0      M   Y        Y             0
# 2  5008804             -13      1      M   Y        Y             0
# 3  5008804             -12      C      M   Y        Y             0
# 4  5008804             -11      C      M   Y        Y             0
#
#    Annual_Income Income_Type   Education_level   Family_Status  \
# 0       427500.0     Working  Higher education  Civil marriage
# 1       427500.0     Working  Higher education  Civil marriage
# 2       427500.0     Working  Higher education  Civil marriage
# 3       427500.0     Working  Higher education  Civil marriage
# 4       427500.0     Working  Higher education  Civil marriage
#
#             Housing   Age  Years_Employed Occupation_Type  CNT_FAM_MEMBERS  \
# 0  Rented apartment  32.0       12.443836             NaN              2.0
# ...

# %%
df['Family_Status'].value_counts()
# Out:
# Family_Status
# Married                 546619
# Single / not married     94335
# Civil marriage           60342
# Separated                45255
# Widow                    31164
# Name: count, dtype: int64

# %%
df['Annual_Income'].max()
# Out:
# 1575000.0

# %%
df.rename(columns = {'ID': 'Id', 'CNT_CHILDREN': 'Children', 'CNT_FAM_MEMBERS': 'Family_size'}, inplace=True)

# %%
df.head()
# Out:
#         Id  MONTHS_BALANCE STATUS Gender Car Property  Children  \
# 0  5008804             -15      X      M   Y        Y         0
# 1  5008804             -14      0      M   Y        Y         0
# 2  5008804             -13      1      M   Y        Y         0
# 3  5008804             -12      C      M   Y        Y         0
# 4  5008804             -11      C      M   Y        Y         0
#
#    Annual_Income Income_Type   Education_level   Family_Status  \
# 0       427500.0     Working  Higher education  Civil marriage
# 1       427500.0     Working  Higher education  Civil marriage
# 2       427500.0     Working  Higher education  Civil marriage
# 3       427500.0     Working  Higher education  Civil marriage
# 4       427500.0     Working  Higher education  Civil marriage
#
#             Housing   Age  Years_Employed Occupation_Type  Family_size  \
# 0  Rented apartment  32.0       12.443836             NaN          2.0
# ...

# %%
df['Children'].value_counts()
# Out:
# Children
# 0     540639
# 1     155638
# 2      70399
# 3       9328
# 4       1224
# 5        324
# 14       111
# 7         46
# 19         6
# Name: count, dtype: int64

# %%
df['Family_size'].value_counts()
# Out:
# Family_size
# 2.0     423723
# 1.0     141477
# 3.0     134894
# 4.0      66990
# 5.0       8999
# 6.0       1196
# 7.0        273
# 15.0       111
# 9.0         46
# 20.0         6
# Name: count, dtype: int64

# %%
df.head()
# Out:
#         Id  MONTHS_BALANCE STATUS Gender Car Property  Children  \
# 0  5008804             -15      X      M   Y        Y         0
# 1  5008804             -14      0      M   Y        Y         0
# 2  5008804             -13      1      M   Y        Y         0
# 3  5008804             -12      C      M   Y        Y         0
# 4  5008804             -11      C      M   Y        Y         0
#
#    Annual_Income Income_Type   Education_level   Family_Status  \
# 0       427500.0     Working  Higher education  Civil marriage
# 1       427500.0     Working  Higher education  Civil marriage
# 2       427500.0     Working  Higher education  Civil marriage
# 3       427500.0     Working  Higher education  Civil marriage
# 4       427500.0     Working  Higher education  Civil marriage
#
#             Housing   Age  Years_Employed Occupation_Type  Family_size  \
# 0  Rented apartment  32.0       12.443836             NaN          2.0
# ...

# %%
dropped_cols = ['MONTHS_BALANCE', 'STATUS']
new_df = df.drop(dropped_cols, axis=1)

# %%
cats = ['Gender', 'Car', 'Property', 'Income_Type', 'Education_level', 'Family_Status', 'Housing', 'Occupation_Type']
nums = ['Children', 'Annual', 'Age', 'Years_Employed', 'Family_size']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_nums = new_df.drop(cats, axis=1)
df_nums.drop('Payments', axis=1, inplace=True)

correlation_matrix = df_nums.corr()

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
# Strong correlation between family size and children, age and years employed. Both make lots of sense

# %%
new_df.drop('Id', axis=1, inplace=True)

# %%
new_df.head()
# Out:
#   Gender Car Property  Children  Annual_Income Income_Type   Education_level  \
# 0      M   Y        Y         0       427500.0     Working  Higher education
# 1      M   Y        Y         0       427500.0     Working  Higher education
# 2      M   Y        Y         0       427500.0     Working  Higher education
# 3      M   Y        Y         0       427500.0     Working  Higher education
# 4      M   Y        Y         0       427500.0     Working  Higher education
#
#     Family_Status           Housing   Age  Years_Employed Occupation_Type  \
# 0  Civil marriage  Rented apartment  32.0       12.443836             NaN
# 1  Civil marriage  Rented apartment  32.0       12.443836             NaN
# 2  Civil marriage  Rented apartment  32.0       12.443836             NaN
# 3  Civil marriage  Rented apartment  32.0       12.443836             NaN
# 4  Civil marriage  Rented apartment  32.0       12.443836             NaN
#
#    Family_size Payments
# 0          2.0  No loan
# ...

# %%
new_df['Occupation_Type'].value_counts()
# Out:
# Occupation_Type
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
new_df['Family_size'].astype(int)
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 777710    2
# 777711    2
# 777712    2
# 777713    2
# 777714    2
# Name: Family_size, Length: 777715, dtype: int64

# %%
plt.hist(new_df['Family_size'])
plt.title(f'Distribution of Family_size')
plt.xlabel('Family_size')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(new_df['Occupation_Type'])
plt.title(f'Distribution of Occupation_Type')
plt.xlabel('Occupation_Type')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 plt.hist(new_df['Occupation_Type'])
#       2 plt.title(f'Distribution of Occupation_Type')
#       3 plt.xlabel('Occupation_Type')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
# ...

# %%
new_df.describe()
# Out:
#             Children  Annual_Income            Age  Years_Employed  \
# count  777715.000000   7.777150e+05  777715.000000   777715.000000
# mean        0.428082   1.885348e+05      43.671326      171.026586
# std         0.745755   1.016225e+05      11.247138      368.243396
# min         0.000000   2.700000e+04      20.000000        0.046575
# 25%         0.000000   1.215000e+05      34.000000        3.449315
# 50%         0.000000   1.620000e+05      43.000000        7.353425
# 75%         1.000000   2.250000e+05      53.000000       15.942466
# max        19.000000   1.575000e+06      68.000000     1000.665753
#
#          Family_size
# count  777715.000000
# mean        2.208837
# std         0.907380
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        20.000000

# %%
new_df[(new_df['Years_Employed'] > 43) & (new_df['Years_Employed'] < 1000)].sort_values(by='Age')
# Out:
#        Gender Car Property  Children  Annual_Income           Income_Type  \
# 551731      F   N        Y         0       180000.0  Commercial associate
# 551745      F   N        Y         0       180000.0  Commercial associate
# 551744      F   N        Y         0       180000.0  Commercial associate
# 551743      F   N        Y         0       180000.0  Commercial associate
# 551742      F   N        Y         0       180000.0  Commercial associate
# 551741      F   N        Y         0       180000.0  Commercial associate
# 551740      F   N        Y         0       180000.0  Commercial associate
# 551746      F   N        Y         0       180000.0  Commercial associate
# 551739      F   N        Y         0       180000.0  Commercial associate
# 551737      F   N        Y         0       180000.0  Commercial associate
# 551736      F   N        Y         0       180000.0  Commercial associate
# 551735      F   N        Y         0       180000.0  Commercial associate
# ...

# %%
new_df[new_df['Years_Employed'] > 1000]
# Out:
#        Gender Car Property  Children  Annual_Income Income_Type  \
# 137         F   N        Y         0       283500.0   Pensioner
# 138         F   N        Y         0       283500.0   Pensioner
# 139         F   N        Y         0       283500.0   Pensioner
# 140         F   N        Y         0       283500.0   Pensioner
# 141         F   N        Y         0       283500.0   Pensioner
# ...       ...  ..      ...       ...            ...         ...
# 777243      F   N        Y         0        67500.0   Pensioner
# 777244      F   N        Y         0        67500.0   Pensioner
# 777245      F   N        Y         0        67500.0   Pensioner
# 777246      F   N        Y         0        67500.0   Pensioner
# 777247      F   N        Y         0        67500.0   Pensioner
#
#                       Education_level Family_Status            Housing   Age  \
# 137                  Higher education     Separated  House / apartment  61.0
# ...

# %%
result_df[result_df['DAYS_EMPLOYED'] >= 0].sort_values(by='DAYS_EMPLOYED')
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 137     5008812             -13      0           F            N
# 500439  5096775             -11      0           F            N
# 500438  5096775              -6      C           F            N
# 500437  5096775             -13      0           F            N
# 500436  5096775             -19      0           F            N
# ...         ...             ...    ...         ...          ...
# 242536  5051057             -14      C           F            N
# 242535  5051057             -19      C           F            N
# 242534  5051057             -16      C           F            N
# 242547  5051058             -24      0           F            N
# 777247  5150423              -5      0           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  Annual_Income NAME_INCOME_TYPE  \
# 137                  Y             0       283500.0        Pensioner
# ...

# %%
result_df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0  5008804             -15      X           M            Y               Y
# 1  5008804             -14      0           M            Y               Y
# 2  5008804             -13      1           M            Y               Y
# 3  5008804             -12      C           M            Y               Y
# 4  5008804             -11      C           M            Y               Y
#
#    CNT_CHILDREN  Annual_Income NAME_INCOME_TYPE NAME_EDUCATION_TYPE  ...  \
# 0             0       427500.0          Working    Higher education  ...
# 1             0       427500.0          Working    Higher education  ...
# 2             0       427500.0          Working    Higher education  ...
# 3             0       427500.0          Working    Higher education  ...
# 4             0       427500.0          Working    Higher education  ...
#
# ...

# %%
# People with 1000 years employment are unemployed 
new_df.loc[new_df['Years_Employed'] > 1000, 'Years_Employed'] = 0

# %%
new_df[new_df['Years_Employed'] > 1000]
# Out:
# Empty DataFrame
# Columns: [Gender, Car, Property, Children, Annual_Income, Income_Type, Education_level, Family_Status, Housing, Age, Years_Employed, Occupation_Type, Family_size, Payments]
# Index: []

# %%
new_df.describe()
# Out:
#             Children  Annual_Income            Age  Years_Employed  \
# count  777715.000000   7.777150e+05  777715.000000   777715.000000
# mean        0.428082   1.885348e+05      43.671326        6.368327
# std         0.745755   1.016225e+05      11.247138        6.684401
# min         0.000000   2.700000e+04      20.000000        0.000000
# 25%         0.000000   1.215000e+05      34.000000        1.180822
# 50%         0.000000   1.620000e+05      43.000000        4.608219
# 75%         1.000000   2.250000e+05      53.000000        9.019178
# max        19.000000   1.575000e+06      68.000000       43.049315
#
#          Family_size
# count  777715.000000
# mean        2.208837
# std         0.907380
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        20.000000

# %%
X = new_df.drop('Payments', axis=1)

# %%
# kde - seaborn

# %%
new_df['Payments'].value_counts()
# Out:
# Payments
# On-time    329420
# Late       301992
# No loan    145894
# Name: count, dtype: int64

# %%
for col in X:
    plt.hist(X[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[156], line 2
#       1 for col in X:
# ----> 2     plt.hist(X[col])
#       3     plt.title(f'Distribution of {col}')
#       4     plt.xlabel(col)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
# ...

# %%
new_df['Occupation_Type'].value_counts()
# Out:
# Occupation_Type
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
na_new_df = new_df.fillna('Missing value')

# %%
na_new_df.head()
# Out:
#   Gender Car Property  Children  Annual_Income Income_Type   Education_level  \
# 0      M   Y        Y         0       427500.0     Working  Higher education
# 1      M   Y        Y         0       427500.0     Working  Higher education
# 2      M   Y        Y         0       427500.0     Working  Higher education
# 3      M   Y        Y         0       427500.0     Working  Higher education
# 4      M   Y        Y         0       427500.0     Working  Higher education
#
#     Family_Status           Housing   Age  Years_Employed Occupation_Type  \
# 0  Civil marriage  Rented apartment  32.0       12.443836   Missing value
# 1  Civil marriage  Rented apartment  32.0       12.443836   Missing value
# 2  Civil marriage  Rented apartment  32.0       12.443836   Missing value
# 3  Civil marriage  Rented apartment  32.0       12.443836   Missing value
# 4  Civil marriage  Rented apartment  32.0       12.443836   Missing value
#
#    Family_size Payments
# 0          2.0  No loan
# ...

# %%
plt.hist(na_new_df['Occupation_Type'])
plt.title(f'Distribution of Occupation_Type')
plt.xlabel('Occupation_Type')
plt.ylabel('Frequency')
plt.show()

# %%
na_new_df['Occupation_Type'].value_counts()
# Out:
# Occupation_Type
# Missing value            240048
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
new_df.describe()
# Out:
#             Children  Annual_Income            Age  Years_Employed  \
# count  777715.000000   7.777150e+05  777715.000000   777715.000000
# mean        0.428082   1.885348e+05      43.671326        6.368327
# std         0.745755   1.016225e+05      11.247138        6.684401
# min         0.000000   2.700000e+04      20.000000        0.000000
# 25%         0.000000   1.215000e+05      34.000000        1.180822
# 50%         0.000000   1.620000e+05      43.000000        4.608219
# 75%         1.000000   2.250000e+05      53.000000        9.019178
# max        19.000000   1.575000e+06      68.000000       43.049315
#
#          Family_size
# count  777715.000000
# mean        2.208837
# std         0.907380
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        20.000000

# %%
ai_new_df = new_df.copy()

# %%
ai_new_df['Annual_Income'] = ai_new_df['Annual_Income']/10000

# %%
ai_new_df.describe()
# Out:
#             Children  Annual_Income            Age  Years_Employed  \
# count  777715.000000  777715.000000  777715.000000   777715.000000
# mean        0.428082      18.853480      43.671326        6.368327
# std         0.745755      10.162245      11.247138        6.684401
# min         0.000000       2.700000      20.000000        0.000000
# 25%         0.000000      12.150000      34.000000        1.180822
# 50%         0.000000      16.200000      43.000000        4.608219
# 75%         1.000000      22.500000      53.000000        9.019178
# max        19.000000     157.500000      68.000000       43.049315
#
#          Family_size
# count  777715.000000
# mean        2.208837
# std         0.907380
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        20.000000

# %%
# take out the outlier from annual income

# %%
new_df[new_df['Annual_Income'] > 900000].describe()
# Out:
#          Children  Annual_Income         Age  Years_Employed  Family_size
# count  409.000000   4.090000e+02  409.000000      409.000000   409.000000
# mean     0.533007   1.316443e+06   37.948655        5.597126     2.166259
# std      0.585370   2.352400e+05   11.473533        1.171401     0.481761
# min      0.000000   9.450000e+05   27.000000        4.273973     2.000000
# 25%      0.000000   1.125000e+06   27.000000        4.449315     2.000000
# 50%      0.000000   1.350000e+06   35.000000        5.035616     2.000000
# 75%      1.000000   1.575000e+06   45.000000        6.791781     2.000000
# max      2.000000   1.575000e+06   62.000000        7.268493     4.000000

# %%
new_df = new_df[new_df['Annual_Income'] <= 900000]

# %%
new_df.describe()
# Out:
#             Children  Annual_Income            Age  Years_Employed  \
# count  777306.000000  777306.000000  777306.000000   777306.000000
# mean        0.428027  187941.323745      43.674337        6.368733
# std         0.745827   98151.760328      11.246259        6.686082
# min         0.000000   27000.000000      20.000000        0.000000
# 25%         0.000000  121500.000000      34.000000        1.180822
# 50%         0.000000  162000.000000      43.000000        4.605479
# 75%         1.000000  225000.000000      53.000000        9.019178
# max        19.000000  900000.000000      68.000000       43.049315
#
#          Family_size
# count  777306.000000
# mean        2.208860
# std         0.907551
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        20.000000

# %%
cats
# Out:
# ['Gender',
#  'Car',
#  'Property',
#  'Income_Type',
#  'Education_level',
#  'Family_Status',
#  'Housing',
#  'Occupation_Type']

# %%
new_df['Education_level'].value_counts()
# Out:
# Education_level
# Secondary / secondary special    524179
# Higher education                 213306
# Incomplete higher                 30329
# Lower secondary                    8655
# Academic degree                     837
# Name: count, dtype: int64

# %%
last_new_df = new_df[new_df['Payments'] != 'No loan']

# %%
last_new_df['Payments'].value_counts()
# Out:
# Payments
# On-time    329420
# Late       301992
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(last_new_df, columns=cats)

# %%
df_encoded
# Out:
#         Children  Annual_Income   Age  Years_Employed  Family_size Payments  \
# 1              0       427500.0  32.0       12.443836          2.0     Late
# 2              0       427500.0  32.0       12.443836          2.0     Late
# 3              0       427500.0  32.0       12.443836          2.0  On-time
# 4              0       427500.0  32.0       12.443836          2.0  On-time
# 5              0       427500.0  32.0       12.443836          2.0  On-time
# ...          ...            ...   ...             ...          ...      ...
# 777710         0       202500.0  53.0        5.934247          2.0  On-time
# 777711         0       202500.0  53.0        5.934247          2.0  On-time
# 777712         0       202500.0  53.0        5.934247          2.0  On-time
# 777713         0       202500.0  53.0        5.934247          2.0  On-time
# 777714         0       202500.0  53.0        5.934247          2.0  On-time
#
# ...

# %%
X = df_encoded.drop('Payments', axis=1)

# %%
X_log = X.copy()

# %%
small_constant = 1

columns_to_log = ['Years_Employed', 'Annual_Income', 'Children', 'Family_size']

for col in columns_to_log:
    X_log[col] = X_log[col].apply(lambda x: np.log(x + small_constant) if x > 0 else np.log(small_constant))

# %%
X_log.head()
# Out:
#    Children  Annual_Income   Age  Years_Employed  Family_size  Gender_F  \
# 1       0.0      12.965712  32.0        2.598521     1.098612     False
# 2       0.0      12.965712  32.0        2.598521     1.098612     False
# 3       0.0      12.965712  32.0        2.598521     1.098612     False
# 4       0.0      12.965712  32.0        2.598521     1.098612     False
# 5       0.0      12.965712  32.0        2.598521     1.098612     False
#
#    Gender_M  Car_N  Car_Y  Property_N  ...  Occupation_Type_Laborers  \
# 1      True  False   True       False  ...                     False
# 2      True  False   True       False  ...                     False
# 3      True  False   True       False  ...                     False
# 4      True  False   True       False  ...                     False
# 5      True  False   True       False  ...                     False
#
#    Occupation_Type_Low-skill Laborers  Occupation_Type_Managers  \
# ...

# %%
X_log[X_log['Family_size']<0]
# Out:
# Empty DataFrame
# ...

# %%
X_scaled = X_log.copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_scaled))

# %% [markdown]
# # Model

# %%
y = last_new_df['Payments']

# %%
y.shape
# Out:
# (631412,)

# %%
X_scaled.shape
# Out:
# (631412, 50)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
lr = LogisticRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X_test, y_test)
# Out:
# 0.5304989586880261

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test, y_test)
# Out:
# 0.7104756776446552

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris

# %%
param_grid = {
    'n_estimators': [50, 100],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10]
}

grid_search = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_

print("Best Hyperparameters:", best_params)

best_model = grid_search.best_estimator_

test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy with Best Model:", test_accuracy)
# Out:
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': None, 'n_estimators': 100}
# Test Accuracy with Best Model: 0.7107765890895845

# %%
from sklearn.metrics import classification_report

rfc_y_pred = rfc.predict(X_test)
print(classification_report(y_test, rfc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Late       0.74      0.61      0.67     60182
#      On-time       0.69      0.80      0.74     66101
#
#     accuracy                           0.71    126283
#    macro avg       0.71      0.71      0.71    126283
# weighted avg       0.71      0.71      0.71    126283

# %% [markdown]
# ## XGBoost

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# %%
import xgboost as xgb
classifier=xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss')


param_grids = {"max_depth":    [None, 4, 5, 10],
              "n_estimators": [100, 150, 200],
              "learning_rate": [0.01, 0.015]}
grid_searchs = GridSearchCV(
    estimator=classifier, 
    param_grid=param_grids, 
    scoring='accuracy',
    cv=4,
    n_jobs=-1
)

# %%
grid_searchs.fit(X_train, y_train_encoded)

best_params = grid_searchs.best_params_

print("Best Hyperparameters:", best_params)

best_model = grid_searchs.best_estimator_

y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy with Best Model:", test_accuracy)
# Out:
# Best Hyperparameters: {'learning_rate': 0.015, 'max_depth': 10, 'n_estimators': 200}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[278], line 10
#       7 best_model = grid_searchs.best_estimator_
#       9 y_pred = best_model.predict(X_test)
# ---> 10 test_accuracy = accuracy_score(y_test, y_pred)
#      11 print("Test Accuracy with Best Model:", test_accuracy)
#
# NameError: name 'accuracy_score' is not defined

# %%
y_encoded = label_encoder.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2)

# %%
from sklearn.metrics import accuracy_score

classifier = xgb.XGBClassifier(
    learning_rate=0.015,
    max_depth=10,
    n_estimators=200,
    objective='binary:logistic',  # for binary classification
    eval_metric='logloss'
)

# Train the model on the training data
classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Evaluate the model
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.6411631019218739
